# %% [markdown]
# # Assignment: Evaluating Data from a Form
#
# A client has been testing a [small form](index.html) to gather some basic data about their client-base. They have brought their findings to you to validate the data they have gathered. You can open the `index.html` page in a browser to take a look at the form.
#
# You have been provided a [dataset of csv records](../../data/form.csv) that contain entries from the form as well as some basic visualizations.The client pointed out that some of the visualizations look incorrect but they're unsure about how to resolve them. You can explore it in the [assignment notebook](assignment.ipynb).
#
# ## Instructions
#
# Use the techniques in this lesson to make recommendations about the form so it captures accurate and consistent information.

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\z-deen\appdata\roaming\python\python310\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\z-deen\appdata\roaming\python\python310\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\z-deen\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading the dataset
form_df = pd.read_csv("form.csv")
print(form_df)
# Out:
#   birth_month       state   pet
# 0     January         NaN  Cats
# 1         JAN          CA  Cats
# 2        Sept      Hawaii   Dog
# 3     january          AK   Dog
# 4        July          RI  Cats
# 5   September  California  Cats
# 6       April          CA   Dog
# 7     January  California  Cats
# 8    November          FL   Dog
# 9    December     Florida  Cats

# %%
form_df['state'].value_counts().plot(kind='bar');
plt.show()

# %%
form_df['birth_month'].value_counts().plot(kind='bar');
plt.show()

# %% [markdown]
# # Solutions:
# # Recommendations

# %% [markdown]
# ### 1. Standardize Input:

# %%
# Import all the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading the dataset
form_df = pd.read_csv("form.csv")
print(form_df)
# Out:
#   birth_month       state   pet
# 0     January         NaN  Cats
# 1         JAN          CA  Cats
# 2        Sept      Hawaii   Dog
# 3     january          AK   Dog
# 4        July          RI  Cats
# 5   September  California  Cats
# 6       April          CA   Dog
# 7     January  California  Cats
# 8    November          FL   Dog
# 9    December     Florida  Cats

# %%
# See the five entries
form_df.head()
# Out:
#   birth_month   state   pet
# 0     January     NaN  Cats
# 1         JAN      CA  Cats
# 2        Sept  Hawaii   Dog
# 3     january      AK   Dog
# 4        July      RI  Cats

# %%
# See the last five entries
form_df.tail()
# Out:
#   birth_month       state   pet
# 5   September  California  Cats
# 6       April          CA   Dog
# 7     January  California  Cats
# 8    November          FL   Dog
# 9    December     Florida  Cats

# %%
form_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   birth_month  10 non-null     object
#  1   state        9 non-null      object
#  2   pet          10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %% [markdown]
# #### 2. Convert all state abbreviations to full names

# %%
# Converting all the state names abbreviations to full name
full_name = {"CA": "California", "AK": "Alaska", "RI": "Rhode Island", "FL": "Florida"}
form_df['state'] = form_df['state'].map(full_name).fillna(form_df['state'])

# %%
print(form_df)
# Out:
#   birth_month         state   pet
# 0     January           NaN  Cats
# 1         JAN    California  Cats
# 2        Sept        Hawaii   Dog
# 3     january        Alaska   Dog
# 4        July  Rhode Island  Cats
# 5   September    California  Cats
# 6       April    California   Dog
# 7     January    California  Cats
# 8    November       Florida   Dog
# 9    December       Florida  Cats

# %% [markdown]
# #### 3. Convert all months abbreviations to full names

# %%
# Converting to title Case
form_df['birth_month'] = form_df['birth_month'].str.title()

# Converting all the months abbreviations to full name
months = {'Jan': 'January', 'Feb': 'February', 'Mar': 'March', 'Apr': 'April', 'May': 'May', 'Jun': 'June', 'Jul': 'July', 'Aug': 'August', 'Sep': 'September', 'Oct': 'October', 'Nov': 'November', 'Dec': 'December'}
months['birth_month'] = form_df['birth_month'].map(months).fillna(form_df['birth_month'])

# %%
print(form_df)
# Out:
#   birth_month         state   pet
# 1         Jan    California  Cats
# 2        Sept        Hawaii   Dog
# 3     January        Alaska   Dog
# 4        July  Rhode Island  Cats
# 5   September    California  Cats
# 6       April    California   Dog
# 7     January    California  Cats
# 8    November       Florida   Dog
# 9    December       Florida  Cats

# %% [markdown]
# ### 4. Handle missing value

# %%
# Drop rows with NaN values
form_df = form_df.dropna(subset=['state'])

# %%
print(form_df)
# Out:
#   birth_month         state   pet
# 1         Jan    California  Cats
# 2        Sept        Hawaii   Dog
# 3     January        Alaska   Dog
# 4        July  Rhode Island  Cats
# 5   September    California  Cats
# 6       April    California   Dog
# 7     January    California  Cats
# 8    November       Florida   Dog
# 9    December       Florida  Cats

# %% [markdown]
# ### 5.  Re-plot Visualizations
#
# ###  Visualize counts of states

# %%
form_df['state'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Visualize counts of birth months

# %%
form_df['birth_month'].value_counts().plot(kind='bar')
plt.show()
